# %% [markdown]
# <a href="https://colab.research.google.com/github/manhtuan09072020-afk/TH_DEEP_LEARNING/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Autoencoder Implementation

# %%
# !pip install Augmentor

import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Conv2DTranspose, Flatten, Reshape
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K

# %% [markdown]
# get_pixel

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

dir_path = 'data/moalla-dataset'
files = os.listdir(dir_path)
print(f"Tổng số ảnh tìm thấy: {len(files)}")
print(f"Danh sách file: {files[:5]}")
# Out:
# Tổng số ảnh tìm thấy: 3
# Danh sách file: ['1b0a1d6b9f7f9ab77dac1ed7afd2c97d.jpg', 'a695e8a3a0e221bc78f3.jpg', '97d0c458881909475008.jpg']

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Conv2D, Conv2DTranspose, Flatten, Reshape
from tensorflow.keras.models import Model

base_dir = 'data'
dir_path = os.path.join(base_dir, 'moalla-dataset')
converted_path = os.path.join(base_dir, 'converted')

if not os.path.exists(converted_path):
    os.makedirs(converted_path)

def process_images(src, dst):
    files = [f for f in os.listdir(src) if f.endswith(('.png', '.jpg', '.jpeg'))]
    for filename in files:
        img = Image.open(os.path.join(src, filename)).convert('L').resize((64, 64))
        img_array = 255 - np.array(img)
        Image.fromarray(img_array).save(os.path.join(dst, filename))

print("Đang xử lý ảnh...")
process_images(dir_path, converted_path)

def load_data(path):
    data = []
    for filename in os.listdir(path):
        img = Image.open(os.path.join(path, filename))
        data.append(np.array(img))
    return np.array(data)

data = load_data(converted_path)
t_size = 0.2 if len(data) > 5 else 0.1
x_train, x_test = train_test_split(data, test_size=t_size, random_state=42)

x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

input_img = Input(shape=(64, 64, 1))

x = Conv2D(32, (3, 3), activation='relu', strides=2, padding='same')(input_img)
x = Conv2D(64, (3, 3), activation='relu', strides=2, padding='same')(x)
x = Flatten()(x)
encoded = Dense(128, activation='relu')(x)

decoder_input = Input(shape=(128,))
x = Dense(16 * 16 * 64, activation='relu')(decoder_input)
x = Reshape((16, 16, 64))(x)
x = Conv2DTranspose(64, (3, 3), activation='relu', strides=2, padding='same')(x)
x = Conv2DTranspose(32, (3, 3), activation='relu', strides=2, padding='same')(x)
decoded = Conv2DTranspose(1, (3, 3), activation='sigmoid', padding='same')(x)

encoder = Model(input_img, encoded)
decoder = Model(decoder_input, decoded)
autoencoder = Model(input_img, decoder(encoder(input_img)))

autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

print("Đang huấn luyện...")
autoencoder.fit(
    x_train, x_train,
    epochs=20,
    batch_size=8,
    shuffle=True,
    validation_data=(x_test, x_test),
    verbose=1
)

num_show = min(len(x_test), 5)
if num_show > 0:
    decoded_imgs = autoencoder.predict(x_test[:num_show])
    plt.figure(figsize=(10, 4))
    for i in range(num_show):
        ax = plt.subplot(2, num_show, i + 1)
        plt.imshow(x_test[i].reshape(64, 64), cmap='gray')
        ax.set_title("Gốc")
        ax.axis('off')
        ax = plt.subplot(2, num_show, i + num_show + 1)
        plt.imshow(decoded_imgs[i].reshape(64, 64), cmap='gray')
        ax.set_title("Tái tạo")
        ax.axis('off')
    plt.show()
else:
    print("Không có đủ ảnh trong tập test để hiển thị!")
# Out:
# Đang xử lý ảnh...
# Đang huấn luyện...
# Epoch 1/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 278ms/step - loss: 0.6930 - val_loss: 0.6904
# Epoch 2/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - loss: 0.6915 - val_loss: 0.6872
# Epoch 3/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 0.6896 - val_loss: 0.6829
# Epoch 4/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 0.6861 - val_loss: 0.6740
# Epoch 5/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 227ms/step - loss: 0.6750 - val_loss: 0.6516
# Epoch 6/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 231ms/step - loss: 0.6422 - val_loss: 0.5899
# Epoch 7/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 263ms/step - loss: 0.5765 - val_loss: 0.4825
# Epoch 8/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 256ms/step - loss: 0.5174 - val_loss: 0.3893
# Epoch 9/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 239ms/step - loss: 0.4703 - val_loss: 0.3686
# Epoch 10/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 237ms/step - loss: 0.4194 - val_loss: 0.3571
# Epoch 11/20
# ...

# %% [markdown]
# Thefining the encoder

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Conv2DTranspose, Flatten
from tensorflow.keras.layers import Reshape, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import TensorBoard

image_width  = 64
image_height = 64
n_epochs     = 15
batch_size   = 128

input_img = Input(shape=(image_width, image_height, 1))

x = Conv2D(32, (3, 3), activation='relu', strides=2, padding='same')(input_img)
x = Conv2D(64, (3, 3), activation='relu', strides=2, padding='same')(x)
encoded_shape = K.int_shape(x)

x = Flatten()(x)
encoded = Dense(128)(x)

encoder = Model(input_img,encoded,name='encoder')
encoder.summary()
# Out:
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_13 (InputLayer)     │ (None, 64, 64, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_12 (Conv2D)              │ (None, 32, 32, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 128)            │     2,097,280 │
# ...

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Conv2D, Conv2DTranspose, Flatten, Reshape
from tensorflow.keras.models import Model

base_dir = 'data'
dir_path = os.path.join(base_dir, 'moalla-dataset')
converted_path = os.path.join(base_dir, 'converted')

if not os.path.exists(converted_path):
    os.makedirs(converted_path)

def prepare_data(src_path, dst_path):
    files = [f for f in os.listdir(src_path) if f.endswith(('.png', '.jpg', '.jpeg'))]
    data = []
    for filename in files:
        img = Image.open(os.path.join(src_path, filename)).convert('L').resize((64, 64))
        img_arr = np.array(img) / 255.0
        data.append(img_arr)
    return np.array(data)

print("Đang tải dữ liệu...")
data = prepare_data(dir_path, converted_path)
data = np.expand_dims(data, axis=-1)

x_train, x_test = train_test_split(data, test_size=0.2, random_state=42)

input_img = Input(shape=(64, 64, 1))
x = Conv2D(32, (3, 3), activation='relu', strides=2, padding='same')(input_img)
x = Conv2D(64, (3, 3), activation='relu', strides=2, padding='same')(x)
x = Flatten()(x)
encoded = Dense(128, activation='relu')(x)
encoder = Model(input_img, encoded, name='encoder')

encoded_input = Input(shape=(128,))
x = Dense(16 * 16 * 64, activation='relu')(encoded_input)
x = Reshape((16, 16, 64))(x)
x = Conv2DTranspose(64, (3, 3), activation='relu', strides=2, padding='same')(x)
x = Conv2DTranspose(32, (3, 3), activation='relu', strides=2, padding='same')(x)
decoded = Conv2DTranspose(1, (3, 3), activation='sigmoid', padding='same')(x)
decoder = Model(encoded_input, decoded, name='decoder')

autoencoder = Model(input_img, decoder(encoder(input_img)), name="autoencoder")
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

print("Bắt đầu huấn luyện...")
autoencoder.fit(
    x_train, x_train,
    epochs=20,
    batch_size=16,
    shuffle=True,
    validation_data=(x_test, x_test)
)

print("Đang hiển thị kết quả...")
num_samples = min(len(x_test), 5)
if num_samples > 0:
    decoded_imgs = autoencoder.predict(x_test[:num_samples])
    plt.figure(figsize=(15, 5))
    for i in range(num_samples):
        ax = plt.subplot(2, num_samples, i + 1)
        plt.imshow(x_test[i].reshape(64, 64), cmap='gray')
        plt.title("Gốc")
        ax.axis('off')
        ax = plt.subplot(2, num_samples, i + num_samples + 1)
        plt.imshow(decoded_imgs[i].reshape(64, 64), cmap='gray')
        plt.title("Tái tạo")
        ax.axis('off')
    plt.show()
else:
    print("Dữ liệu quá ít để hiển thị!")
# Out:
# Đang tải dữ liệu...
# Bắt đầu huấn luyện...
# Epoch 1/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 421ms/step - loss: 0.6926 - val_loss: 0.6774
# Epoch 2/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - loss: 0.6803 - val_loss: 0.5845
# Epoch 3/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - loss: 0.6184 - val_loss: 0.4592
# Epoch 4/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - loss: 0.6155 - val_loss: 0.4498
# Epoch 5/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 181ms/step - loss: 0.5682 - val_loss: 0.4966
# Epoch 6/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 0.5739 - val_loss: 0.4891
# Epoch 7/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.5666 - val_loss: 0.4535
# Epoch 8/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - loss: 0.5449 - val_loss: 0.4279
# Epoch 9/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 0.5364 - val_loss: 0.4218
# Epoch 10/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step - loss: 0.5354 - val_loss: 0.4228
# Epoch 11/20
# ...

# %% [markdown]
# Defining the Autoencoder

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Conv2D, Conv2DTranspose, Flatten, Reshape
from tensorflow.keras.models import Model


base_dir = 'data'
dir_path = os.path.join(base_dir, 'moalla-dataset')

def prepare_data(src_path):
    files = [f for f in os.listdir(src_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    data = []
    for filename in files:
        img = Image.open(os.path.join(src_path, filename)).convert('L').resize((64, 64))
        img_arr = np.array(img) / 255.0
        data.append(img_arr)
    return np.array(data)

print("Đang tải dữ liệu...")
data = prepare_data(dir_path)
data = np.expand_dims(data, axis=-1)

x_train, x_test = train_test_split(data, test_size=0.2, random_state=42)

input_img = Input(shape=(64, 64, 1))
x = Conv2D(32, (3, 3), activation='relu', strides=2, padding='same')(input_img)
x = Conv2D(64, (3, 3), activation='relu', strides=2, padding='same')(x)
x = Flatten()(x)
encoded = Dense(128, activation='relu')(x)
encoder = Model(input_img, encoded, name='encoder')

encoded_input = Input(shape=(128,))
x = Dense(16 * 16 * 64, activation='relu')(encoded_input)
x = Reshape((16, 16, 64))(x)
x = Conv2DTranspose(64, (3, 3), activation='relu', strides=2, padding='same')(x)
x = Conv2DTranspose(32, (3, 3), activation='relu', strides=2, padding='same')(x)
decoded = Conv2DTranspose(1, (3, 3), activation='sigmoid', padding='same')(x)
decoder = Model(encoded_input, decoded, name='decoder')

autoencoder = Model(input_img, decoder(encoder(input_img)), name="autoencoder")
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
autoencoder.summary()

print("Bắt đầu huấn luyện...")
autoencoder.fit(
    x_train, x_train,
    epochs=20,
    batch_size=16,
    shuffle=True,
    validation_data=(x_test, x_test)
)

print("Hiển thị ảnh tái tạo...")
num_show = min(len(x_test), 5)
if num_show > 0:
    decoded_imgs = autoencoder.predict(x_test[:num_show])
    plt.figure(figsize=(15, 5))
    for i in range(num_show):
        ax = plt.subplot(2, num_show, i + 1)
        plt.imshow(x_test[i].reshape(64, 64), cmap='gray')
        plt.title("Gốc")
        ax.axis('off')
        ax = plt.subplot(2, num_show, i + num_show + 1)
        plt.imshow(decoded_imgs[i].reshape(64, 64), cmap='gray')
        plt.title("Tái tạo")
        ax.axis('off')
    plt.show()
# Out:
# Đang tải dữ liệu...
# Model: "autoencoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_18 (InputLayer)     │ (None, 64, 64, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoder (Functional)            │ (None, 128)            │     2,116,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder (Functional)            │ (None, 64, 64, 1)      │     2,169,217 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,285,313 (16.35 MB)
#  Trainable params: 4,285,313 (16.35 MB)
#  Non-trainable params: 0 (0.00 B)
# Bắt đầu huấn luyện...
# Epoch 1/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 696ms/step - loss: 0.6931 - val_loss: 0.6909
# Epoch 2/20
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Giả sử bạn đã chạy lệnh: h = autoencoder.fit(...) trước đó
# 'h' chính là đối tượng history chứa dữ liệu huấn luyện

# 1. Xác định số lượng epochs đã chạy
n_epochs = len(history.history['loss'])
N = np.arange(0, n_epochs)

# 2. Thiết lập khung hình
plt.figure(figsize=(10, 6)) # Bạn có thể chỉnh kích thước tại đây

# 3. Vẽ đường train_loss và val_loss
plt.plot(N, history.history['loss'], label='train_loss', color='red')
plt.plot(N, history.history['val_loss'], label='val_loss', color='blue')

# 4. Gán nhãn cho các trục và tiêu đề
plt.title('Training Loss and Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss/Accuracy')

# 5. Hiển thị chú thích (legend) và grid để dễ nhìn
plt.legend(loc='upper right')
plt.grid(True) # Thêm lưới giống trong hình bạn gửi

# 6. Hiển thị biểu đồ
plt.show()

# %% [markdown]
# Lab 4

# %%
# ==========================================
# 2.1 Nạp thư viện
# ==========================================
import numpy as np
import keras
from keras import layers
from keras.datasets import mnist
import matplotlib.pyplot as plt

# ==========================================
# 2.2 Nạp dataset
# ==========================================
(x_train, _), (x_test, _) = mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

print("Kích thước x_train:", x_train.shape)
print("Kích thước x_test:", x_test.shape)

# 2.3 Xây dựng mô hình Autoencoder
encoding_dim = 32
input_img = keras.Input(shape=(784,))
encoded = layers.Dense(encoding_dim, activation='relu')(input_img)
decoded = layers.Dense(784, activation='sigmoid')(encoded)
autoencoder = keras.Model(input_img, decoded)
encoder = keras.Model(input_img, encoded)
encoded_input = keras.Input(shape=(encoding_dim,))
decoder_layer = autoencoder.layers[-1]
decoder = keras.Model(encoded_input, decoder_layer(encoded_input))

#2.3 Xây dựng mô hình autuencoder
encoding_dim = 32
input_img = keras.Input(shape=(784,))

encoded = layers.Dense(encoding_dim, activation='relu')(input_img)
decoded = layers.Dense(784, activation='sigmoid')(encoded)

autoencoder = keras.Model(input_img, decoded)
encoder = keras.Model(input_img, encoded)

encoded_input = keras.Input(shape=(encoding_dim,))
decoder_layer = autoencoder.layers[-1]
decoder = keras.Model(encoded_input, decoder_layer(encoded_input))

# 2.4 Huấn luyện mô hình
autoencoder.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))

# 2.5 Dự báo loại ảnh sử dụng Autoencoder
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

# 2.6 Hiển thị ảnh từ mô hình Autoencoder
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # Hiển thị ảnh gốc
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Hiển thị ảnh tái tạo
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Kích thước x_train: (60000, 784)
# Kích thước x_test: (10000, 784)
# Epoch 1/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.0108 - loss: 0.2758 - val_accuracy: 0.0138 - val_loss: 0.1893
# Epoch 2/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.0120 - loss: 0.1708 - val_accuracy: 0.0124 - val_loss: 0.1537
# Epoch 3/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0118 - loss: 0.1447 - val_accuracy: 0.0122 - val_loss: 0.1339
# Epoch 4/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0112 - loss: 0.1285 - val_accuracy: 0.0093 - val_loss: 0.1212
# Epoch 5/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0116 - loss: 0.1182 - val_accuracy: 0.0108 - val_loss: 0.1127
# Epoch 6/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.0123 - loss: 0.1111 - val_accuracy: 0.0115 - val_loss: 0.1069
# Epoch 7/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0119 - loss: 0.1061 - val_accuracy: 0.0106 - val_loss: 0.1029
# ...

# %% [markdown]
# 3. CẢI TIẾN AUTOENCODER

# %% [markdown]
# 3.1 Thêm L1 Regularization

# %%
encoding_dim = 32
input_img = keras.Input(shape=(784,))

encoded = layers.Dense(encoding_dim, activation='relu',
                       activity_regularizer=keras.regularizers.l1(10e-5))(input_img)
decoded = layers.Dense(784, activation='sigmoid')(encoded)

autoencoder = keras.Model(input_img, decoded)
encoder = keras.Model(input_img, encoded)

encoded_input = keras.Input(shape=(encoding_dim,))
decoder_layer = autoencoder.layers[-1]
decoder = keras.Model(encoded_input, decoder_layer(encoded_input))

autoencoder.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
autoencoder.fit(x_train, x_train,
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.0143 - loss: 0.6559 - val_accuracy: 0.0161 - val_loss: 0.6155
# Epoch 2/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.0150 - loss: 0.5832 - val_accuracy: 0.0161 - val_loss: 0.5535
# Epoch 3/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.0150 - loss: 0.5274 - val_accuracy: 0.0161 - val_loss: 0.5038
# Epoch 4/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.0150 - loss: 0.4827 - val_accuracy: 0.0161 - val_loss: 0.4637
# Epoch 5/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.4466 - val_accuracy: 0.0161 - val_loss: 0.4314
# Epoch 6/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0150 - loss: 0.4174 - val_accuracy: 0.0161 - val_loss: 0.4050
# Epoch 7/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.0146 - loss: 0.3935 - val_accuracy: 0.0161 - val_loss: 0.3834
# Epoch 8/100
# ...

# %% [markdown]
# 3.2 Thêm nhiều tầng (Multi-layers)

# %%
encoding_dim = 32
input_img = keras.Input(shape=(784,))

encoded = layers.Dense(128, activation='relu')(input_img)
encoded = layers.Dense(64, activation='relu')(encoded)
encoded = layers.Dense(encoding_dim, activation='relu')(encoded)

decoded = layers.Dense(784, activation='sigmoid')(encoded)

autoencoder = keras.Model(input_img, decoded)
encoder = keras.Model(input_img, encoded)

encoded_input = keras.Input(shape=(32,))
decoder_layer = autoencoder.layers[-1]
decoder = keras.Model(encoded_input, decoder_layer(encoded_input))

autoencoder.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
autoencoder.fit(x_train, x_train,
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.0098 - loss: 0.2626 - val_accuracy: 0.0086 - val_loss: 0.1730
# Epoch 2/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.0113 - loss: 0.1565 - val_accuracy: 0.0121 - val_loss: 0.1406
# Epoch 3/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step - accuracy: 0.0120 - loss: 0.1334 - val_accuracy: 0.0139 - val_loss: 0.1248
# Epoch 4/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.0110 - loss: 0.1216 - val_accuracy: 0.0103 - val_loss: 0.1156
# Epoch 5/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.0105 - loss: 0.1135 - val_accuracy: 0.0109 - val_loss: 0.1092
# Epoch 6/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.0104 - loss: 0.1082 - val_accuracy: 0.0100 - val_loss: 0.1047
# Epoch 7/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.0115 - loss: 0.1048 - val_accuracy: 0.0128 - val_loss: 0.1026
# Epoch 8/100
# ...
